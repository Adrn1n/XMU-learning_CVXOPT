# %%
import sympy as sp
import numpy as np
# import plotly.graph_objects as go
import matplotlib.pyplot as plt

sp.init_printing(use_latex="mathjax")

# %%
f, x, y, z = sp.symbols("f x y z")

# %% [markdown]
# # (1)

# %%
f = sp.exp(x) - x**2 + 3 * x + 4

df_dx = sp.diff(f, x)

display(df_dx)
# Out:
#         x
# -2⋅x + ℯ  + 3

# %%
x_grid = np.linspace(-2, 0, 1000)

# %%
# fig = go.Figure()

# fig.add_trace(
#     go.Scatter(
#         x=x_grid,
#         y=[float(f.subs(x, x_val)) for x_val in x_grid],
#         mode="lines",
#         name="f",
#     )
# )

# fig.update_layout(
#     title="f", xaxis_title="x", yaxis_title="f", showlegend=True, width=800, height=600
# )
# fig.show()

# %%
fig = plt.figure(figsize=(8, 6))

plt.plot(
    x_grid, [float(f.subs(x, x_val)) for x_val in x_grid], label="f", linestyle="-"
)

plt.title("f")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

# %%
eps = 1e-6
max_iter = 1000
X_0 = -1

# %%
x_ = X_0
for _ in range(max_iter):
    x_ = (X_0 - f.subs(x, X_0) / (df_dx.subs(x, X_0))).evalf()
    if abs(f.subs(x, x_)) < eps:
        break
    X_0 = x_

display(x_, (f.subs(x, x_)).evalf())
# Out:
# -1.06783057567706
# -4.09190643813062e-7

# %% [markdown]
# # (2)

# %% [markdown]
# ## 1

# %%
f = sp.exp(x) - x**2 + 3 * x + 4

df_dx = sp.diff(f, x)

display(df_dx)
# Out:
#         x
# -2⋅x + ℯ  + 3

# %%
x_grid = np.linspace(-2, 0, 1000)

# %%
# fig = go.Figure()

# fig.add_trace(
#     go.Scatter(
#         x=x_grid,
#         y=[float(f.subs(x, x_val)) for x_val in x_grid],
#         mode="lines",
#         name="f",
#     )
# )

# fig.update_layout(
#     title="f", xaxis_title="x", yaxis_title="f", showlegend=True, width=800, height=600
# )
# fig.show()

# %%
fig = plt.figure(figsize=(8, 6))

plt.plot(
    x_grid, [float(f.subs(x, x_val)) for x_val in x_grid], label="f", linestyle="-"
)

plt.title("f")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

# %%
eps = 1e-6
max_iter = 1000
X_0 = -1

# %%
x_ = X_0
for _ in range(max_iter):
    x_ = (X_0 - f.subs(x, X_0) / (df_dx.subs(x, X_0))).evalf()
    if abs(f.subs(x, x_)) < eps:
        break
    X_0 = x_

display(x_, (f.subs(x, x_)).evalf())
# Out:
# -1.06783057567706
# -4.09190643813062e-7

# %% [markdown]
# ## 2

# %%
f = 6 * sp.sin(x) + 5 * x - 2

df_dx = sp.diff(f, x)

display(df_dx)
# Out:
# 6⋅cos(x) + 5

# %%
x_grid = np.linspace(0, 1, 1000)

# %%
# fig = go.Figure()

# fig.add_trace(
#     go.Scatter(
#         x=x_grid,
#         y=[float(f.subs(x, x_val)) for x_val in x_grid],
#         mode="lines",
#         name="f",
#     )
# )

# fig.update_layout(
#     title="f", xaxis_title="x", yaxis_title="f", showlegend=True, width=800, height=600
# )
# fig.show()

# %%
fig = plt.figure(figsize=(8, 6))

plt.plot(
    x_grid, [float(f.subs(x, x_val)) for x_val in x_grid], label="f", linestyle="-"
)

plt.title("f")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

# %%
eps = 1e-6
max_iter = 1000
X_0 = -0.2

# %%
x_ = X_0
for _ in range(max_iter):
    x_ = (X_0 - f.subs(x, X_0) / (df_dx.subs(x, X_0))).evalf()
    if abs(f.subs(x, x_)) < eps:
        break
    X_0 = x_

display(x_, (f.subs(x, x_)).evalf())
# Out:
# 0.182368654373964
# -9.96980276113391e-14

# %% [markdown]
# ## 3

# %%
f = 5 * x + sp.ln(x) - 10000

df_dx = sp.diff(f, x)

display(df_dx)
# Out:
#     1
# 5 + ─
#     x

# %%
x_grid = np.linspace(1500, 2500, 1000)

# %%
# fig = go.Figure()

# fig.add_trace(
#     go.Scatter(
#         x=x_grid,
#         y=[float(f.subs(x, x_val)) for x_val in x_grid],
#         mode="lines",
#         name="f",
#     )
# )

# fig.update_layout(
#     title="f", xaxis_title="x", yaxis_title="f", showlegend=True, width=800, height=600
# )
# fig.show()

# %%
fig = plt.figure(figsize=(8, 6))

plt.plot(
    x_grid, [float(f.subs(x, x_val)) for x_val in x_grid], label="f", linestyle="-"
)

plt.title("f")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

# %%
eps = 1e-6
max_iter = 1000
X_0 = 2000

# %%
x_ = X_0
for _ in range(max_iter):
    x_ = (X_0 - f.subs(x, X_0) / (df_dx.subs(x, X_0))).evalf()
    if abs(f.subs(x, x_)) < eps:
        break
    X_0 = x_

display(x_, (f.subs(x, x_)).evalf())
# Out:
# 1998.47997151094
# -2.88956714555866e-7

# %% [markdown]
# # (1)

# %% [markdown]
# ## 1

# %%
z = 4 * (x**2) + y**2 + 5

grad_z = sp.Matrix(sp.derive_by_array(z, (x, y)))
hess_z = sp.hessian(z, (x, y))

display(grad_z, hess_z)
# Out:
# ⎡8⋅x⎤
# ⎢   ⎥
# ⎣2⋅y⎦
# ⎡8  0⎤
# ⎢    ⎥
# ⎣0  2⎦

# %%
eps = 1e-6
max_iter = 1000
X_0 = np.array([3, 4], dtype=float)

# %%
path = [np.append(X_0, float(z.subs([(x, X_0[0]), (y, X_0[1])])))]
for _ in range(max_iter):
    X_0 = path[-1][:2]
    X_0 = np.array(
        sp.Matrix(X_0) - hess_z.inv() @ (grad_z.subs([(x, X_0[0]), (y, X_0[1])])),
        dtype=float,
    )
    path.append(np.append(X_0, float(z.subs([(x, X_0[0].item()), (y, X_0[1].item())]))))
    if abs(path[-2][-1] - path[-1][-1]) < eps:
        break

path = np.array(path)

display(path[-1])
# Out:
# array([0., 0., 5.])

# %%
x_grid, y_grid = np.meshgrid(np.linspace(-4, 4, 100), np.linspace(-4, 4, 100))

# %%
# fig = go.Figure()

# fig.add_trace(
#     go.Surface(
#         x=x_grid,
#         y=y_grid,
#         z=np.array(
#             [
#                 float(z.subs([(x, x_val), (y, y_val)]))
#                 for x_val, y_val in zip(x_grid.flatten(), y_grid.flatten())
#             ]
#         ).reshape(x_grid.shape),
#         colorscale="viridis",
#         opacity=0.85,
#         colorbar=dict(len=0.75),
#     )
# )
# fig.add_trace(
#     go.Scatter3d(
#         x=path[:, 0],
#         y=path[:, 1],
#         z=path[:, 2],
#         mode="lines+markers",
#         line=dict(width=1, color="red"),
#         marker=dict(size=2, color="red"),
#         name="Path",
#         showlegend=True,
#     )
# )

# fig.update_layout(
#     title="Plot",
#     scene=dict(xaxis_title="x", yaxis_title="y", zaxis_title="z"),
#     width=800,
#     height=600,
# )
# fig.show()

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection="3d")

surf = ax.plot_surface(
    x_grid,
    y_grid,
    np.array(
        [
            float(z.subs([(x, x_val), (y, y_val)]))
            for x_val, y_val in zip(x_grid.flatten(), y_grid.flatten())
        ]
    ).reshape(x_grid.shape),
    cmap="viridis",
    alpha=0.875,
)
ax.plot(
    path[:, 0],
    path[:, 1],
    path[:, 2],
    color="red",
    marker="o",
    markersize=2,
    linewidth=1,
    label="Path",
)

plt.colorbar(surf, shrink=0.75)
ax.set_title("Plot")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
ax.legend()
plt.show()

# %% [markdown]
# ## 2

# %%
z = x * y + y**2

grad_z = sp.Matrix(sp.derive_by_array(z, (x, y)))
hess_z = sp.hessian(z, (x, y))

display(grad_z, hess_z)
# Out:
# ⎡   y   ⎤
# ⎢       ⎥
# ⎣x + 2⋅y⎦
# ⎡0  1⎤
# ⎢    ⎥
# ⎣1  2⎦

# %%
eps = 1e-6
max_iter = 1000
X_0 = np.array([2, 2], dtype=float)

# %%
path = [np.append(X_0, float(z.subs([(x, X_0[0]), (y, X_0[1])])))]
for _ in range(max_iter):
    X_0 = path[-1][:2]
    X_0 = np.array(
        sp.Matrix(X_0) - hess_z.inv() @ (grad_z.subs([(x, X_0[0]), (y, X_0[1])])),
        dtype=float,
    )
    path.append(np.append(X_0, float(z.subs([(x, X_0[0].item()), (y, X_0[1].item())]))))
    if abs(path[-2][-1] - path[-1][-1]) < eps:
        break

path = np.array(path)

display(path[-1])
# Out:
# array([0., 0., 0.])

# %%
x_grid, y_grid = np.meshgrid(np.linspace(-6, 6, 100), np.linspace(-6, 6, 100))

# %%
# fig = go.Figure()

# fig.add_trace(
#     go.Surface(
#         x=x_grid,
#         y=y_grid,
#         z=np.array(
#             [
#                 float(z.subs([(x, x_val), (y, y_val)]))
#                 for x_val, y_val in zip(x_grid.flatten(), y_grid.flatten())
#             ]
#         ).reshape(x_grid.shape),
#         colorscale="viridis",
#         opacity=0.85,
#         colorbar=dict(len=0.75),
#     )
# )
# fig.add_trace(
#     go.Scatter3d(
#         x=path[:, 0],
#         y=path[:, 1],
#         z=path[:, 2],
#         mode="lines+markers",
#         line=dict(width=1, color="red"),
#         marker=dict(size=2, color="red"),
#         name="Path",
#         showlegend=True,
#     )
# )

# fig.update_layout(
#     title="Plot",
#     scene=dict(xaxis_title="x", yaxis_title="y", zaxis_title="z"),
#     width=800,
#     height=600,
# )
# fig.show()

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection="3d")

surf = ax.plot_surface(
    x_grid,
    y_grid,
    np.array(
        [
            float(z.subs([(x, x_val), (y, y_val)]))
            for x_val, y_val in zip(x_grid.flatten(), y_grid.flatten())
        ]
    ).reshape(x_grid.shape),
    cmap="viridis",
    alpha=0.875,
)
ax.plot(
    path[:, 0],
    path[:, 1],
    path[:, 2],
    color="red",
    marker="o",
    markersize=2,
    linewidth=1,
    label="Path",
)

plt.colorbar(surf, shrink=0.75)
ax.set_title("Plot")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
ax.legend()
plt.show()
