# %%
import sympy as sp
import numpy as np
import plotly.graph_objects as go
import matplotlib.pyplot as plt

sp.init_printing(use_latex="mathjax")

# %%
f, x = sp.symbols("f x")

# %% [markdown]
# # (1)

# %%
f = sp.exp(x) - x**2 + 3 * x + 4
f_func = sp.lambdify((x), f, "numpy")
df_dx = sp.diff(f, x)

display(df_dx)
# Out:
#         x
# -2⋅x + ℯ  + 3

# %%
x_grid = np.linspace(-2, 0, 1000)

# %%
# fig = go.Figure()

# fig.add_trace(go.Scatter(x=x_grid, y=f_func(x_grid), mode="lines", name="f"))

# fig.update_layout(
#     title="f", xaxis_title="x", yaxis_title="f", showlegend=True, width=800, height=600
# )
# fig.show()

# %%
fig = plt.figure(figsize=(8, 6))

plt.plot(x_grid, f_func(x_grid), label="f", linestyle="-")

plt.title("f")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

# %%
eps = 1e-6
max_iter = 1000
x_0 = -1

# %%
x_ = x_0
for _ in range(max_iter):
    x_ = (x_0 - f.subs(x, x_0) / (df_dx.subs(x, x_0))).evalf()
    if abs(x_ - x_0) < eps:
        break
    x_0 = x_

display(x_, (f.subs(x, x_)).evalf())
# Out:
# -1.06783050099926
# -4.38538094726937e-15

# %% [markdown]
# # (2)

# %% [markdown]
# ## 1

# %%
f = sp.exp(x) - x**2 + 3 * x + 4
f_func = sp.lambdify((x), f, "numpy")
df_dx = sp.diff(f, x)

display(df_dx)
# Out:
#         x
# -2⋅x + ℯ  + 3

# %%
x_grid = np.linspace(-2, 0, 1000)

# %%
# fig = go.Figure()

# fig.add_trace(go.Scatter(x=x_grid, y=f_func(x_grid), mode="lines", name="f"))

# fig.update_layout(
#     title="f", xaxis_title="x", yaxis_title="f", showlegend=True, width=800, height=600
# )
# fig.show()

# %%
fig = plt.figure(figsize=(8, 6))

plt.plot(x_grid, f_func(x_grid), label="f", linestyle="-")

plt.title("f")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

# %%
eps = 1e-6
max_iter = 1000
x_0 = -1

# %%
x_ = x_0
for _ in range(max_iter):
    x_ = (x_0 - f.subs(x, x_0) / (df_dx.subs(x, x_0))).evalf()
    if abs(x_ - x_0) < eps:
        break
    x_0 = x_

display(x_, (f.subs(x, x_)).evalf())
# Out:
# -1.06783050099926
# -4.38538094726937e-15

# %% [markdown]
# ## 2

# %%
f = 6 * sp.sin(x) + 5 * x - 2
f_func = sp.lambdify((x), f, "numpy")
df_dx = sp.diff(f, x)

display(df_dx)
# Out:
# 6⋅cos(x) + 5

# %%
x_grid = np.linspace(0, 1, 1000)

# %%
# fig = go.Figure()

# fig.add_trace(go.Scatter(x=x_grid, y=f_func(x_grid), mode="lines", name="f"))

# fig.update_layout(
#     title="f", xaxis_title="x", yaxis_title="f", showlegend=True, width=800, height=600
# )
# fig.show()

# %%
fig = plt.figure(figsize=(8, 6))

plt.plot(x_grid, f_func(x_grid), label="f", linestyle="-")

plt.title("f")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

# %%
eps = 1e-6
max_iter = 1000
x_0 = -0.2

# %%
x_ = x_0
for _ in range(max_iter):
    x_ = (x_0 - f.subs(x, x_0) / (df_dx.subs(x, x_0))).evalf()
    if abs(x_ - x_0) < eps:
        break
    x_0 = x_

display(x_, (f.subs(x, x_)).evalf())
# Out:
# 0.182368654373964
# -9.96980276113391e-14

# %% [markdown]
# ## 3

# %%
f = 5 * x + sp.ln(x) - 10000
f_func = sp.lambdify((x), f, "numpy")
df_dx = sp.diff(f, x)

display(df_dx)
# Out:
#     1
# 5 + ─
#     x

# %%
x_grid = np.linspace(1500, 2500, 1000)

# %%
# fig = go.Figure()

# fig.add_trace(go.Scatter(x=x_grid, y=f_func(x_grid), mode="lines", name="f"))

# fig.update_layout(
#     title="f", xaxis_title="x", yaxis_title="f", showlegend=True, width=800, height=600
# )
# fig.show()

# %%
fig = plt.figure(figsize=(8, 6))

plt.plot(x_grid, f_func(x_grid), label="f", linestyle="-")

plt.title("f")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

# %%
eps = 1e-6
max_iter = 1000
x_0 = 2000

# %%
x_ = x_0
for _ in range(max_iter):
    x_ = (x_0 - f.subs(x, x_0) / (df_dx.subs(x, x_0))).evalf()
    if abs(x_ - x_0) < eps:
        break
    x_0 = x_

display(x_, (f.subs(x, x_)).evalf())
# Out:
# 1998.47997156873
# 4.76951811378967e-13
